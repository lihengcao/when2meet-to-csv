# %% [markdown]
# <a href="https://colab.research.google.com/github/caoliheng/when2meet-to-csv/blob/main/when2meet_to_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Inspired by the following [script](https://gist.github.com/camtheman256/3125e18ba20e90b6252678714e5102fd).
#
# My modified version is given here.
# ```javascript
# function myShowSlot(Time,TimeString="") {
#     e = document.getElementById("ParticipantTimeZone");
#     timezone = e[e.selectedIndex].value;
#
#     if (isNaN(Time)||(Time==0)) {
#       document.getElementById("AvailableDate").innerHTML = "&nbsp;";
#       document.getElementById("Available").innerHTML = "";
#       document.getElementById("Unavailable").innerHTML = "";
#       document.getElementById("AvailableFraction").innerHTML = "0/"+AvailableIDs.length;
#       return;
#     }
#
#     AvailableList = "";
#     UnavailableList = "";
#     AvailableCount=0;
#     Count=0;
#     for (var i=0;i<AvailableIDs.length;i++) {
#       Count++;
#       var found = (-1 != AvailableAtSlot[TimeOfSlot.indexOf(Time)].indexOf(AvailableIDs[i]) );
#       if (found) {
#         AvailableList += PeopleNames[PeopleIDs.indexOf(AvailableIDs[i])]+"<br>";
#         AvailableCount++;
#       } else
#         UnavailableList += PeopleNames[PeopleIDs.indexOf(AvailableIDs[i])]+"<br>";
#     }
#     document.getElementById("Available").innerHTML = AvailableList;
#     document.getElementById("Unavailable").innerHTML = UnavailableList;
#     document.getElementById("AvailableFraction").innerHTML = AvailableCount+"/"+Count;
#
#     var date = new Date(Time*1000);
#
#     var monthNames = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"];
#     var monthName = monthNames[moment.tz(date,timezone).format('M')-1];
#
#     var dayOfWeekNames = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"];
#
#     var dayOfWeekName = dayOfWeekNames[moment.tz(date,timezone).format('e')];
#
#     var dayOfMonth = moment.tz(date,timezone).format('D');
#
#     var hours = moment.tz(date,timezone).format('H');
#     var suffix = "am"; if (hours>=12) suffix="pm";
#     if (hours>12) hours=hours-12;
#     if (hours==0) hours=12;
#     var minutes = moment.tz(date,timezone).format('mm');
#     var year = moment.tz(date,timezone).format('YYYY');
#     var timeString = hours + ':' + minutes.substr(-2) + " " + suffix ;
#
#     return dayOfWeekName + ' '+ timeString;
#   }
#
# function exportData() {
#     const peopleMap = {};
#     for(let i = 0; i < PeopleIDs.length; i++) {
#         peopleMap[PeopleIDs[i]] = PeopleNames[i];
#     }
#     nameAtSlot = AvailableAtSlot.map(e => e.map(i => peopleMap[i]));
#     timedNames = TimeOfSlot.map((e, i) => [myShowSlot(e), nameAtSlot[i]]);
#     return JSON.stringify(timedNames);
# }
#
# exportData();
# ```
#
# Go to the when2meet, paste this into the browser console (F12, then look for console), and copy the result. If you're running into problems, remember that the output is already a string, so do not put the result inside another string. In other words, just paste the output, and do not put in inside quotes.

# %%
#@title Paste here! Double click here to hide/show this block
# paste the result here:
w2m = "\"[[\\\"Sunday 9:00 am\\\", [\\\"Ben Guirakhoo\\\", \\\"Lilly Gottlieb\\\", \\\"Tony Zhang\\\", \\\"Lemons\\\", \\\"Thomas Tai\\\"]], [\\\"Sunday 9:15 am\\\", [\\\"Ben Guirakhoo\\\", \\\"Lilly Gottlieb\\\", \\\"Tony Zhang\\\", \\\"Lemons\\\", \\\"Thomas Tai\\\"]], [\\\"Sunday 9:30 am\\\", [\\\"Ben Guirakhoo\\\", \\\"Lilly Gottlieb\\\", \\\"Tony Zhang\\\", \\\"Lemons\\\", \\\"Thomas Tai\\\"]], [\\\"Sunday 9:45 am\\\", [\\\"Ben Guirakhoo\\\", \\\"Lilly Gottlieb\\\", \\\"Tony Zhang\\\", \\\"Lemons\\\", \\\"Thomas Tai\\\"]], [\\\"Sunday 10:00 am\\\", [\\\"Ben Guirakhoo\\\", \\\"Lilly Gottlieb\\\", \\\"Tony Zhang\\\", \\\"Lemons\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\"]], [\\\"Sunday 10:15 am\\\", [\\\"Ben Guirakhoo\\\", \\\"Lilly Gottlieb\\\", \\\"Tony Zhang\\\", \\\"Lemons\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\"]], [\\\"Sunday 10:30 am\\\", [\\\"Ben Guirakhoo\\\", \\\"Lilly Gottlieb\\\", \\\"Tony Zhang\\\", \\\"Lemons\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\"]], [\\\"Sunday 10:45 am\\\", [\\\"Ben Guirakhoo\\\", \\\"Lilly Gottlieb\\\", \\\"Tony Zhang\\\", \\\"Lemons\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\"]], [\\\"Sunday 11:00 am\\\", [\\\"Ben Guirakhoo\\\", \\\"Lilly Gottlieb\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Lemons\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"
\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Alexandra\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 11:15 am\\\", [\\\"Soji\\\", \\\"Ben Guirakhoo\\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Alexandra\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 11:30 am\\\", [\\\"Soji\\\", \\\"Ben Guirakhoo\\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Alexandra\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 11:45 am\\\", [\\\"Soji\\\", \\\"Ben Guirakhoo\\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Alexandra\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 12:00 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Skye\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 12:15 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Skye\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 12:30 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Skye\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 12:45 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Skye\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 1:00 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 1:15 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 1:30 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"mei\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 1:45 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Naz\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"mei\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 2:00 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"mei\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 2:15 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"mei\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\"]], [\\\"Saturday 2:30 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"mei\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 2:45 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"mei\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 3:00 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"mei\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 3:15 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"mei\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 3:30 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Carlo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"mei\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 3:45 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Carlo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"mei\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 4:00 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Carlo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 4:15 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Carlo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Kyle Wang\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 4:30 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Carlo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 4:45 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Carlo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Cat\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Alexandra\\\", \\\"Lucia\\\", \\\"Skye\\\", \\\"Neil Kumar\\\", \\\"Caiden McDonough\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 5:00 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 5:15 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 5:30 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 5:45 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 6:00 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 6:15 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 6:30 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Lemons\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 6:45 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Lemons\\\", \\\"Neil Kumar\\\", \\\"Allen\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 7:00 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Lemons\\\", \\\"Neil Kumar\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Ally\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 7:15 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Lemons\\\", \\\"Neil Kumar\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Ally\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 7:30 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Lemons\\\", \\\"Neil Kumar\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Ally\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 7:45 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Lemons\\\", \\\"Neil Kumar\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Ally\\\", \\\"Igor Rodrigues\\\"]], [\\\"Saturday 8:00 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Lemons\\\", \\\"Neil Kumar\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Ally\\\"]], [\\\"Saturday 8:15 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Lemons\\\", \\\"Neil Kumar\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Ally\\\"]], [\\\"Saturday 8:30 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Lemons\\\", \\\"Neil Kumar\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Ally\\\"]], [\\\"Saturday 8:45 pm\\\", [\\\"Soji\\\", \\\"Analeah\\\", \\\"Ben Guirakhoo\\\", \\\"Liheng\\\", \\\"Lilly Gottlieb\\\", \\\"Ellawyn\\\", \\\"Matthew Shen\\\", \\\"Tony Zhang\\\", \\\"Bharti\\\", \\\"Lemons\\\", \\\"Neil Kumar\\\", \\\"Victor DIng\\\", \\\"Thomas Tai\\\", \\\"Ally\\\"]]]\""

# %%
import pandas as pd
import json
from collections import defaultdict

VERBOSE = False
# read json
data = json.loads(json.loads(w2m))  # works if you load it twice


data_dict = defaultdict(list)
times_sort_order = {}  # might be redundant

for i, e in enumerate(data):
    for j in range(len(e[1])):
        data_dict[e[0]].append(e[1][j])

    times_sort_order[e[0]] = i

if VERBOSE:
    print("first entry:\t\t", data[0])
    print("data_dict:\t\t", data_dict)
    print("sort order:\t\t", times_sort_order)
    print("sort order keys:\t", times_sort_order.keys())

# inspired by https://stackoverflow.com/questions/41964618/boolean-matrix-form-pythons-dict-of-lists
values = sorted(list(set([ x for y in data_dict.values() for x in y])), key=lambda s: s.lower())  # also puts in alphabetical order
boolean_map = {}
for key in data_dict.keys():
    boolean_map[key] = [ 1 if value in data_dict[key] else 0 for value in values ]
df = pd.DataFrame(boolean_map, index=values)
print("Copy the following:")
df.to_csv()
